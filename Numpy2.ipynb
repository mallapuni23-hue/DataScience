# %% [markdown]
# # Automatic Datatypes

# %%
import numpy as np
a = np.array([1,2,3,4,5.6])
print(a)
print(a.dtype)
# Out:
# [1.  2.  3.  4.  5.6]
# float64

# %% [markdown]
# # Zeros

# %%
import numpy as np
a = np.zero([5])
print(a)
