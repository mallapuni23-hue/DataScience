# %%
import pandas as pd
df = pd.read_csv("employee_data_dirty.csv")
print(df)
# Out:
#     ID              Name    Age  Gender         City Department   Salary  \
# 0    1       Ram Sharma    25.0    Male    Kathmandu         IT  45000.0
# 1    2        Sita Thapa   28.0  Female      Pokhara         HR  52000.0
# 2    3           Hari KC   22.0    Male    kathmandu         IT  40000.0
# 3    4         Anita Rai    NaN  Female   Biratnagar    Finance  55000.0
# 4    5     Bikash Gurung   30.0    Male      Pokhara         IT  60000.0
# 5    6    Pratiksha Lama   27.0  Female    Kathmandu         HR  50000.0
# 6    7   Ramesh Shrestha   35.0    Male     Lalitpur      Sales  70000.0
# 7    8         Sunita KC   26.0  Female       Butwal    Finance  58000.0
# 8    9   Deepak Adhikari   29.0    Male    Bharatpur         IT  62000.0
# 9   10       Puja Gurung   24.0  Female    Kathmandu  Marketing  48000.0
# 10  11       Rohan Singh   31.0    male      Pokhara         IT  75000.0
# 11  12     Manisha Karki   23.0  Female    kathmandu         HR      NaN
# ...

# %%
df['Name'] = df['Name'].str.strip()
cols_to_check = df.columns.drop('ID')
df = df.drop_duplicates(subset=cols_to_check, keep = 'first').reset_index(drop=True)
# whole column check garxa
# subset['name]
# yesto ma name duplicate matra check garxa
print(df)
# Out:
#     ID             Name        Age  Gender        City Department  \
# 0    1       Ram Sharma  25.000000    Male   Kathmandu         IT
# 1    2       Sita Thapa  28.000000  Female     Pokhara         HR
# 2    3          Hari KC  22.000000    Male   Kathmandu         IT
# 3    4        Anita Rai  30.000000  Female  Biratnagar    Finance
# 4    5    Bikash Gurung  30.000000    Male     Pokhara         IT
# 5    6   Pratiksha Lama  27.000000  Female   Kathmandu         HR
# 6    7  Ramesh Shrestha  35.000000    Male    Lalitpur      Sales
# 7    8        Sunita KC  26.000000  Female      Butwal    Finance
# 8    9  Deepak Adhikari  29.000000    Male   Bharatpur         IT
# 9   10      Puja Gurung  24.000000  Female   Kathmandu  Marketing
# 10  11      Rohan Singh  31.000000    Male     Pokhara         IT
# 11  12    Manisha Karki  23.000000  Female   Kathmandu         HR
# 12  13         Suman KC  27.000000    Male    Lalitpur         IT
# ...

# %%
print(df.isnull())
# Out:
#        ID   Name    Age  Gender   City  Department  Salary  Email  Join_Date
# 0   False  False  False   False  False       False   False  False      False
# 1   False  False  False   False  False       False   False  False      False
# 2   False  False  False   False  False       False   False  False      False
# 3   False  False   True   False  False       False   False  False      False
# 4   False  False  False   False  False       False   False  False      False
# 5   False  False  False   False  False       False   False  False      False
# 6   False  False  False   False  False       False   False  False      False
# 7   False  False  False   False  False       False   False  False      False
# 8   False  False  False   False  False       False   False  False      False
# 9   False  False  False   False  False       False   False  False      False
# 10  False  False  False   False  False       False   False  False      False
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          47 non-null     int64
#  1   Name        47 non-null     str
#  2   Age         46 non-null     float64
#  3   Gender      47 non-null     str
#  4   City        47 non-null     str
#  5   Department  47 non-null     str
#  6   Salary      46 non-null     float64
#  7   Email       47 non-null     str
#  8   Join_Date   47 non-null     str
# dtypes: float64(2), int64(1), str(6)
# memory usage: 3.4 KB

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].mean())
print(df)
# Out:
#     ID             Name    Age  Gender         City Department        Salary  \
# 0    1       Ram Sharma   25.0    Male    Kathmandu         IT  45000.000000
# 1    2       Sita Thapa   28.0  Female      Pokhara         HR  52000.000000
# 2    3          Hari KC   22.0    Male    kathmandu         IT  40000.000000
# 3    4        Anita Rai    NaN  Female   Biratnagar    Finance  55000.000000
# 4    5    Bikash Gurung   30.0    Male      Pokhara         IT  60000.000000
# 5    6   Pratiksha Lama   27.0  Female    Kathmandu         HR  50000.000000
# 6    7  Ramesh Shrestha   35.0    Male     Lalitpur      Sales  70000.000000
# 7    8        Sunita KC   26.0  Female       Butwal    Finance  58000.000000
# 8    9  Deepak Adhikari   29.0    Male    Bharatpur         IT  62000.000000
# 9   10      Puja Gurung   24.0  Female    Kathmandu  Marketing  48000.000000
# 10  11      Rohan Singh   31.0    male      Pokhara         IT  75000.000000
# ...

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
print(df)
# Out:
#     ID             Name         Age  Gender         City Department  \
# 0    1       Ram Sharma   25.000000    Male    Kathmandu         IT
# 1    2       Sita Thapa   28.000000  Female      Pokhara         HR
# 2    3          Hari KC   22.000000    Male    kathmandu         IT
# 3    4        Anita Rai   30.195652  Female   Biratnagar    Finance
# 4    5    Bikash Gurung   30.000000    Male      Pokhara         IT
# 5    6   Pratiksha Lama   27.000000  Female    Kathmandu         HR
# 6    7  Ramesh Shrestha   35.000000    Male     Lalitpur      Sales
# 7    8        Sunita KC   26.000000  Female       Butwal    Finance
# 8    9  Deepak Adhikari   29.000000    Male    Bharatpur         IT
# 9   10      Puja Gurung   24.000000  Female    Kathmandu  Marketing
# 10  11      Rohan Singh   31.000000    male      Pokhara         IT
# 11  12    Manisha Karki   23.000000  Female    kathmandu         HR
# 12  13         Suman KC   27.000000    Male     Lalitpur         IT
# ...

# %%
df.loc[df['Salary'] < 0, 'Salary'] = None

df['Salary'] = df['Salary'].fillna(df['Salary'].mean())

print(df)
# Out:
#     ID             Name         Age  Gender         City Department  \
# 0    1       Ram Sharma   25.000000    Male    Kathmandu         IT
# 1    2       Sita Thapa   28.000000  Female      Pokhara         HR
# 2    3          Hari KC   22.000000    Male    kathmandu         IT
# 3    4        Anita Rai   30.195652  Female   Biratnagar    Finance
# 4    5    Bikash Gurung   30.000000    Male      Pokhara         IT
# 5    6   Pratiksha Lama   27.000000  Female    Kathmandu         HR
# 6    7  Ramesh Shrestha   35.000000    Male     Lalitpur      Sales
# 7    8        Sunita KC   26.000000  Female       Butwal    Finance
# 8    9  Deepak Adhikari   29.000000    Male    Bharatpur         IT
# 9   10      Puja Gurung   24.000000  Female    Kathmandu  Marketing
# 10  11      Rohan Singh   31.000000    male      Pokhara         IT
# 11  12    Manisha Karki   23.000000  Female    kathmandu         HR
# 12  13         Suman KC   27.000000    Male     Lalitpur         IT
# ...

# %%
df['City'] = df['City'].str.title()
print(df)
# Out:
#     ID             Name         Age  Gender         City Department  \
# 0    1       Ram Sharma   25.000000    Male    Kathmandu         IT
# 1    2       Sita Thapa   28.000000  Female      Pokhara         HR
# 2    3          Hari KC   22.000000    Male    Kathmandu         IT
# 3    4        Anita Rai   30.195652  Female   Biratnagar    Finance
# 4    5    Bikash Gurung   30.000000    Male      Pokhara         IT
# 5    6   Pratiksha Lama   27.000000  Female    Kathmandu         HR
# 6    7  Ramesh Shrestha   35.000000    Male     Lalitpur      Sales
# 7    8        Sunita KC   26.000000  Female       Butwal    Finance
# 8    9  Deepak Adhikari   29.000000    Male    Bharatpur         IT
# 9   10      Puja Gurung   24.000000  Female    Kathmandu  Marketing
# 10  11      Rohan Singh   31.000000    male      Pokhara         IT
# 11  12    Manisha Karki   23.000000  Female    Kathmandu         HR
# 12  13         Suman KC   27.000000    Male     Lalitpur         IT
# ...

# %%
df['City'] = df['City'].str.strip()
print(df)
# Out:
#     ID             Name         Age  Gender        City Department  \
# 0    1       Ram Sharma   25.000000    Male   Kathmandu         IT
# 1    2       Sita Thapa   28.000000  Female     Pokhara         HR
# 2    3          Hari KC   22.000000    Male   Kathmandu         IT
# 3    4        Anita Rai   30.195652  Female  Biratnagar    Finance
# 4    5    Bikash Gurung   30.000000    Male     Pokhara         IT
# 5    6   Pratiksha Lama   27.000000  Female   Kathmandu         HR
# 6    7  Ramesh Shrestha   35.000000    Male    Lalitpur      Sales
# 7    8        Sunita KC   26.000000  Female      Butwal    Finance
# 8    9  Deepak Adhikari   29.000000    Male   Bharatpur         IT
# 9   10      Puja Gurung   24.000000  Female   Kathmandu  Marketing
# 10  11      Rohan Singh   31.000000    male     Pokhara         IT
# 11  12    Manisha Karki   23.000000  Female   Kathmandu         HR
# 12  13         Suman KC   27.000000    Male    Lalitpur         IT
# ...

# %%
df['Gender'] = df['Gender'].str.title()
print(df)
# Out:
#     ID             Name         Age  Gender        City Department  \
# 0    1       Ram Sharma   25.000000    Male   Kathmandu         IT
# 1    2       Sita Thapa   28.000000  Female     Pokhara         HR
# 2    3          Hari KC   22.000000    Male   Kathmandu         IT
# 3    4        Anita Rai   30.195652  Female  Biratnagar    Finance
# 4    5    Bikash Gurung   30.000000    Male     Pokhara         IT
# 5    6   Pratiksha Lama   27.000000  Female   Kathmandu         HR
# 6    7  Ramesh Shrestha   35.000000    Male    Lalitpur      Sales
# 7    8        Sunita KC   26.000000  Female      Butwal    Finance
# 8    9  Deepak Adhikari   29.000000    Male   Bharatpur         IT
# 9   10      Puja Gurung   24.000000  Female   Kathmandu  Marketing
# 10  11      Rohan Singh   31.000000    Male     Pokhara         IT
# 11  12    Manisha Karki   23.000000  Female   Kathmandu         HR
# 12  13         Suman KC   27.000000    Male    Lalitpur         IT
# ...

# %%
df = df[df['Email'].str.contains('@',na=False)]
df = df.dropna()
print(df)
# Out:
#     ID             Name         Age  Gender        City Department  \
# 0    1       Ram Sharma   25.000000    Male   Kathmandu         IT
# 1    2       Sita Thapa   28.000000  Female     Pokhara         HR
# 2    3          Hari KC   22.000000    Male   Kathmandu         IT
# 3    4        Anita Rai   30.195652  Female  Biratnagar    Finance
# 4    5    Bikash Gurung   30.000000    Male     Pokhara         IT
# 5    6   Pratiksha Lama   27.000000  Female   Kathmandu         HR
# 6    7  Ramesh Shrestha   35.000000    Male    Lalitpur      Sales
# 7    8        Sunita KC   26.000000  Female      Butwal    Finance
# 8    9  Deepak Adhikari   29.000000    Male   Bharatpur         IT
# 9   10      Puja Gurung   24.000000  Female   Kathmandu  Marketing
# 10  11      Rohan Singh   31.000000    Male     Pokhara         IT
# 11  12    Manisha Karki   23.000000  Female   Kathmandu         HR
# 12  13         Suman KC   27.000000    Male    Lalitpur         IT
# ...

# %%
df['Age'] = df['Age'].round().astype(float)
pd.set_option('display.float_format', '{:.6f}'.format)
print(df)
# Out:
#     ID             Name        Age  Gender        City Department  \
# 0    1       Ram Sharma  25.000000    Male   Kathmandu         IT
# 1    2       Sita Thapa  28.000000  Female     Pokhara         HR
# 2    3          Hari KC  22.000000    Male   Kathmandu         IT
# 3    4        Anita Rai  30.000000  Female  Biratnagar    Finance
# 4    5    Bikash Gurung  30.000000    Male     Pokhara         IT
# 5    6   Pratiksha Lama  27.000000  Female   Kathmandu         HR
# 6    7  Ramesh Shrestha  35.000000    Male    Lalitpur      Sales
# 7    8        Sunita KC  26.000000  Female      Butwal    Finance
# 8    9  Deepak Adhikari  29.000000    Male   Bharatpur         IT
# 9   10      Puja Gurung  24.000000  Female   Kathmandu  Marketing
# 10  11      Rohan Singh  31.000000    Male     Pokhara         IT
# 11  12    Manisha Karki  23.000000  Female   Kathmandu         HR
# 12  13         Suman KC  27.000000    Male    Lalitpur         IT
# ...

# %%
df['Join_Date'] = pd.to_datetime(
    df['Join_Date'],
    errors='coerce',
    format='mixed'
)

df['Join_Date'] = df['Join_Date'].dt.strftime('%Y-%m-%d')
print(df)
# Out:
#     ID             Name        Age  Gender        City Department  \
# 0    1       Ram Sharma  25.000000    Male   Kathmandu         IT
# 1    2       Sita Thapa  28.000000  Female     Pokhara         HR
# 2    3          Hari KC  22.000000    Male   Kathmandu         IT
# 3    4        Anita Rai  30.000000  Female  Biratnagar    Finance
# 4    5    Bikash Gurung  30.000000    Male     Pokhara         IT
# 5    6   Pratiksha Lama  27.000000  Female   Kathmandu         HR
# 6    7  Ramesh Shrestha  35.000000    Male    Lalitpur      Sales
# 7    8        Sunita KC  26.000000  Female      Butwal    Finance
# 8    9  Deepak Adhikari  29.000000    Male   Bharatpur         IT
# 9   10      Puja Gurung  24.000000  Female   Kathmandu  Marketing
# 10  11      Rohan Singh  31.000000    Male     Pokhara         IT
# 11  12    Manisha Karki  23.000000  Female   Kathmandu         HR
# 12  13         Suman KC  27.000000    Male    Lalitpur         IT
# ...

# %%
df.to_csv("clean_employees_data.csv",index = True)
