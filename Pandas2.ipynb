# %%
# create a series of 5 numbers and print value greater than 20
import pandas as pd
data = [10,25,30,15,35]
s =pd.Series(data)
print(s[s>20])
# Out:
# 1    25
# 2    30
# 4    35
# dtype: int64

# %%
# create a dataframe of 5 students with their names, ages, and grades
import pandas as pd
Data ={
    "Name" : ["Samiksha", "Sita", "Prasuna", "Purnima", "Priya"],
    "Age" : [21,23,20,22,16],
    "Grades" : ["A","B", "C", "A", "A"]
}
df = pd.DataFrame(Data)
print(df)
# Out:
#        Name  Age Grades
# 0  Samiksha   21      A
# 1      Sita   23      B
# 2   Prasuna   20      C
# 3   Purnima   22      A
# 4     Priya   16      A

# %% [markdown]
# # Read / Write CSV

# %%
import pandas as pd
df = pd.read_csv("Titanic.csv")
print(df)
# Out:
#      Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
# ..          ...       ...     ...     ...   ...    ...    ...      ...
# 886         886         0       2    male  27.0      0      0  13.0000
# 887         887         1       1  female  19.0      0      0  30.0000
# 888         888         0       3  female   NaN      1      2  23.4500
# 889         889         1       1    male  26.0      0      0  30.0000
# 890         890         0       3    male  32.0      0      0   7.7500
#
#     embarked   class    who  adult_male deck  embark_town alive  alone
# ...

# %%
df.to_csv("Titanic_copy.csv", index = False)
