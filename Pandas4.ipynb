# %%
import seaborn as sns
print(sns.__version__)
# Out:
# 0.13.2

# %%
import matplotlib 
print(matplotlib.__version__)
# Out:
# 3.11.1

# %%
# data visualization

# %%
import matplotlib.pyplot as plt
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
sales = [1000,1200,1500,1300,1700,1600,1800,2000,2200,2100,2300,2500]
plt.figure(figsize=(12,8))
plt.plot(months, sales)

plt.show()

# %% [markdown]
# # Adding Title and Axis Labels

# %%
import matplotlib.pyplot as plt
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
sales = [1000,1200,1500,1300,1700,1600,1800,2000,2200,2100,2300,2500]
plt.figure(figsize=(12,8))
plt.plot(months, sales)
plt.title('Monthly Sales Data')
plt.xlabel('Month')
plt.ylabel('Sales')

plt.show()

# %% [markdown]
# # Markers and line styles

# %%
import matplotlib.pyplot as plt
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
sales = [1000,1200,1500,1300,1700,1600,1800,2000,2200,2100,2300,2500]
plt.figure(figsize=(12,8))
plt.plot(months, sales, marker ='o', linestyle = '-', color = 'b')
plt.title('Monthly Sales Data')
plt.xlabel('Month')
plt.ylabel('Sales')

plt.show()

# %%
import matplotlib.pyplot as plt
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
sales = [1000,1200,1500,1300,1700,1600,1800,2000,2200,2100,2300,2500]
plt.figure(figsize=(12,8))
plt.plot(months, sales, marker ='s', linestyle = '--', color = 'r')
plt.title('Monthly Sales Data')
plt.xlabel('Month')
plt.ylabel('Sales')

plt.show()

# %%
import matplotlib.pyplot as plt
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
sales = [1000,1200,1500,1300,1700,1600,1800,2000,2200,2100,2300,2500]
plt.figure(figsize=(12,8))
plt.plot(months, sales, marker ='^', linestyle = ':', color = 'r')
plt.title('Monthly Sales Data')
plt.xlabel('Month')
plt.ylabel('Sales')

plt.show()

# %%
import matplotlib.pyplot as plt
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
sales = [1000,1200,1500,1300,1700,1600,1800,2000,2200,2100,2300,2500]
plt.figure(figsize=(12,8))
plt.plot(months, sales, marker ='*', linestyle = '-.', color = 'r')
plt.title('Monthly Sales Data')
plt.xlabel('Month')
plt.ylabel('Sales')

plt.show()

# %% [markdown]
# # Adding Grid

# %%
import matplotlib.pyplot as plt
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
sales = [1000,1200,1500,1300,1700,1600,1800,2000,2200,2100,2300,2500]
plt.figure(figsize=(12,8))
plt.plot(months, sales, marker ='o', linestyle = '-', color = 'r')
plt.title('Monthly Sales Data')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.grid()

plt.show()

# %% [markdown]
# # Multiple Lines

# %%
import matplotlib.pyplot as plt
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
product_a = [1000,1200,1500,1300,1700,1600,1800,2000,2200,2100,2300,2500]
product_b = [2400,2300,2100,1900,1800,2000,1500,1500,1800,1100,1400,1600]
plt.figure(figsize=(12,8))
plt.plot(months, product_a, marker ='o', linestyle = '-', color = 'g', label = 'Product A')
plt.plot(months, product_b, marker ='s', linestyle = '--', color = 'r', label = 'Product B')
plt.title('Monthly Sales Data for Product A and B')
plt.xlabel('Month')
plt.ylabel('Sales')

plt.legend()

plt.show()

# %% [markdown]
# # Bar Graph

# %%
students = ['Alice', 'Bob', 'Charlie', 'David', 'Eva']
marks = [85,92,78,90,88]

plt.bar(students, marks , color = 'lightblue', edgecolor = 'black')
plt.title('Student Marks')
plt.xlabel('Students')
plt.ylabel('Marks')


plt.show()
# Out:
# C:\Users\malla\AppData\Local\Temp\ipykernel_46508\517761666.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
students = ['Alice', 'Bob', 'Charlie', 'David', 'Eva']
marks = [85,92,78,90,88]

plt.barh(students, marks , color = 'lightblue', edgecolor = 'black')
plt.title('Student Marks')
plt.xlabel('Students')
plt.ylabel('Marks')


plt.show()

# %% [markdown]
# # Histogram

# %%
marks = [85,92,78,90,88,95,80,88,92,85,90,87,93,89,91,86,84,88,92,90]
plt.hist(marks, bins = 10, color = 'pink', edgecolor = 'black')

plt.title('distribution of student Marks')
plt.xlabel('Marks')
plt.ylabel('frequency')
plt.show()
